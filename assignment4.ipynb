# %%
import numpy as np

# %%
number = np.random.randint(low=0, high=2000, size=(1000,))

# %%
number=list(number)

# %%
number
# Out:
# [1698,
#  1515,
#  1970,
#  236,
#  1273,
#  1184,
#  926,
#  1072,
#  1623,
#  1840,
#  1398,
#  601,
#  240,
#  172,
#  358,
#  756,
#  405,
#  379,
#  1664,
#  1043,
#  127,
#  1095,
#  101,
#  426,
#  383,
#  1852,
#  16,
#  1040,
#  1622,
#  1122,
#  1205,
#  1128,
#  884,
#  985,
#  924,
#  114,
#  1293,
#  562,
#  364,
#  245,
#  1596,
#  452,
#  1667,
#  939,
#  606,
#  1204,
#  1668,
#  1740,
#  349,
#  1007,
#  76,
#  815,
#  593,
#  1230,
#  285,
#  791,
#  932,
#  1988,
#  166,
#  612,
#  1515,
#  677,
#  999,
#  902,
#  594,
#  3,
#  1622,
#  607,
#  653,
#  502,
#  1222,
#  919,
#  626,
#  918,
#  1579,
#  134,
#  1368,
#  975,
#  9,
#  1282,
#  156,
#  1544,
#  1566,
#  1101,
#  1059,
#  354,
#  447,
#  1499,
#  794,
#  1085,
#  1919,
#  1530,
#  272,
#  189,
#  550,
#  1657,
#  673,
#  553,
#  750,
#  845,
#  1589,
#  724,
#  221,
#  464,
#  991,
#  474,
#  1098,
#  258,
#  1905,
#  946,
#  1428,
#  1078,
#  445,
#  1183,
#  1558,
#  1566,
#  744,
#  1757,
#  1020,
# ...

# %%
def is_even(number):
    if number % 2==0:
        return True
    else:
        return False
    return is_even(number)

# %%
is_even(512)
# Out:
# True

# %%
def is_prime(number,divisor=2):
    if number==1 or number==2:
        return True
    if number % divisor == 0:
        return False
    if divisor==(number-1):
        return True
        divisor=divisor+1
    return is_prime(number,divisor+1)

# %%
is_prime(511)
# Out:
# False

# %%
prime=[]
even=[]
def even_prime_list_creation(number,divisor=2):
    if number==1 or number==2:
        prime.append(number)
    else:
        if number % 2 == 0:
            even.append(number)
        else:
            if divisor==(number-1):
                prime.append(number)
                divisor=divisor+1
                return even_prime_list_creation(number,divisor=2)
           
    y=[prime,even]
    return y

# %%
y=even_prime_list_creation(number,divisor=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-794789432fde> in <module>
# ----> 1 y=even_prime_list_creation(number,divisor=2)
#
# <ipython-input-9-a580aaf73407> in even_prime_list_creation(number, divisor)
#       5         prime.append(number)
#       6     else:
# ----> 7         if number % 2 == 0:
#       8             even.append(number)
#       9         else:
#
# TypeError: unsupported operand type(s) for %: 'list' and 'int'

# %%
prime=[]
even=[]
def even_prime_list_creat(number):
    if number==1 or number==2:
        prime.append(number)
    else:
        if is_even(number)==True:
                even.append(number)
        else:
            if is_prime(number,divisor=2)==True:
                    prime.append(number)
    return even_prime_list_creat(number)
    z=[prime,even]
    return z

# %%
z=even_prime_list_creat(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-057b889ee20e> in <module>
# ----> 1 z=even_prime_list_creat(number)
#
# <ipython-input-11-981d3decafbc> in even_prime_list_creat(number)
#       5         prime.append(number)
#       6     else:
# ----> 7         if is_even(number)==True:
#       8                 even.append(number)
#       9         else:
#
# <ipython-input-5-8723a0fc1738> in is_even(number)
#       1 def is_even(number):
# ----> 2     if number % 2==0:
#       3         return True
#       4     else:
#       5         return False
#
# TypeError: unsupported operand type(s) for %: 'list' and 'int'
